# %% [markdown]
# <a href="https://colab.research.google.com/github/ghdakrk/computr_vision/blob/main/image_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pixel 세로 * 가로, ndarray, tensor

# %%
! pip install scipy==1.1.0
# Out:
# Requirement already satisfied: scipy==1.1.0 in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from scipy==1.1.0) (1.19.5)

# %%
# gray scale
import scipy.misc

img_gray = scipy.misc.face(gray=True)
img_gray.shape
# Out:
# (768, 1024)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(img_gray[:15, :15], annot=True, fmt='d', cmap=plt.cm.bone)
plt.axis("off")
plt.show()

# %%
from sklearn.datasets import load_sample_images

dataset = load_sample_images()
img_rgb = dataset.images[1]
img_rgb.shape
# Out:
# (427, 640, 3)

# %%
# hsv
import numpy as np
from matplotlib.colors import hsv_to_rgb

V, H = np.mgrid[0:1:100j, 0:1:360j]
S = np.ones_like(V)

HSV_S100 = np.dstack((H, S*1.0, V))
RGB_S100 = hsv_to_rgb(HSV_S100)
RGB_S100.shape
# Out:
# (100, 360, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(RGB_S100)
plt.show()

# %%
# pillow
import PIL
PIL.__version__
# Out:
# '7.1.2'

# %%
from PIL import Image

img_logo_png = Image.open("./logo.png")
img_logo_png.size
# Out:
# (120, 160)

# %%
img_logo_png
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=120x160 at 0x7F950F9F7C90>

# %%
img_logo_png.save("./logo.bmp")
img_logo_bmp = Image.open("./logo.bmp")

# %%
img_logo_bmp
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=120x160 at 0x7F950F8BCC90>

# %%
img_logo_array = np.array(img_logo_bmp)

plt.imshow(img_logo_array)
plt.axis("off")
plt.show()

# %%
Image.fromarray(img_logo_array)
# Out:
# <PIL.Image.Image image mode=RGB size=120x160 at 0x7F9506326350>

# %%
img_logo_png.resize((200,200))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F95063BA450>

# %%
img_logo_thumbnail = img_logo_png.copy()
img_logo_thumbnail.thumbnail((150, 50))
img_logo_thumbnail
# Out:
# <PIL.Image.Image image mode=RGB size=37x50 at 0x7F950F8BC5D0>

# %%
img_logo_png.rotate(45)
# Out:
# <PIL.Image.Image image mode=RGB size=120x160 at 0x7F95063B83D0>

# %%
img_logo_png.crop((10,10,200,200))
# Out:
# <PIL.Image.Image image mode=RGB size=190x190 at 0x7F95063D8CD0>

# %%
#scikit-image
import skimage
skimage.__version__
# Out:
# '0.18.3'

# %%
import skimage.data
img_astro = skimage.data.astronaut()
img_astro.shape
# Out:
# (512, 512, 3)

# %%
skimage.io.imsave("astronaut.png", img_astro)
img_astro2 = skimage.io.imread("astronaut.png")

# %%
from skimage import color
plt.subplot(131)
plt.axis("off")
plt.imshow(img_astro)

plt.subplot(132)
plt.axis("off")
plt.imshow(color.rgb2gray(img_astro), cmap=plt.cm.gray)

plt.subplot(133)
plt.axis("off")
plt.imshow(color.rgb2hsv(img_astro))
